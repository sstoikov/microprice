# %%
import pandas as pd
import numpy as np
from ib_insync import *
util.startLoop()  # uncomment this line when in a notebook
import datetime
import time
from IPython.display import display, clear_output
# %matplotlib inline

# %%
# Connect with IB
# Please reach out to me directly if you need any detailed setup for IB API
ib = IB()
ib.connect('127.0.0.1', 7496, clientId=10)
# Out:
# <IB connected to 127.0.0.1:7496 clientId=10>

# %%
df0 = pd.read_csv('SSO_20190101_.csv', index_col=0)
df0
# Out:
# C:\Users\Lorenzo Shen\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                               time  bidSize    bid  askSize    ask
# 0        2019-01-02 09:00:00+00:00    200.0  77.99    700.0  91.11
# 1        2019-01-02 09:00:17+00:00    200.0  77.99    100.0  91.80
# 2        2019-01-02 09:00:25+00:00    200.0  77.99    200.0  93.93
# 3        2019-01-02 09:08:27+00:00    700.0  89.11    700.0  89.34
# 4        2019-01-02 09:08:27+00:00   1400.0  89.11   1400.0  89.34
# ...                            ...      ...    ...      ...    ...
# 1194676  2019-01-04 18:12:26+00:00    100.0  94.73   3100.0  94.78
# 1194677  2019-01-04 18:12:26+00:00   3000.0  94.75   3100.0  94.78
# 1194678  2019-01-04 18:12:27+00:00   3000.0  94.75   3000.0  94.78
# 1194679  2019-01-04 18:12:33+00:00   3000.0  94.75   3100.0  94.78
# 1194680  2019-01-04 18:12:33+00:00   3000.0  94.75   3000.0  94.78
#
# [1194681 rows x 5 columns]

# %%
# Define start time at any date but specify as shown below, accurate to second
# Leave end time as empty if you do not want to end at some point

start = datetime.datetime(2019, 1, 5, 9, 30, 0, tzinfo=datetime.timezone.utc)
# start = df.iloc[-1].time + datetime.timedelta(0,1)
end = ""
# start_time = time.time()
df = pd.DataFrame()

while start.replace(tzinfo=None) < datetime.datetime(2019, 1, 10):
    tickers = ib.reqHistoricalTicks(Stock('SSO', 'SMART', 'USD'), start, end, 1000, 'BID_ASK', useRth=False)
    for t in tickers:
        to_append = [t.time.isoformat(' ', 'seconds'), t.sizeBid, t.priceBid, t.sizeAsk, t.priceAsk]
        to_series = pd.Series(to_append)
        df = df.append(to_series, ignore_index=True, sort=False)
    start = tickers[-1].time + datetime.timedelta(0,1)
# Out:
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-c07cba16e2ec> in <module>
#       9
#      10 while start.replace(tzinfo=None) < datetime.datetime(2019, 1, 10):
# ---> 11     tickers = ib.reqHistoricalTicks(Stock('SSO', 'SMART', 'USD'), start, end, 1000, 'BID_ASK', useRth=False)
#      12     for t in tickers:
#      13         to_append = [t.time.isoformat(' ', 'seconds'), t.sizeBid, t.priceBid, t.sizeAsk, t.priceAsk]
#
# ~\Anaconda3\lib\site-packages\ib_insync\ib.py in reqHistoricalTicks(self, contract, startDateTime, endDateTime, numberOfTicks, whatToShow, useRth, ignoreSize, miscOptions)
#    1080             self.reqHistoricalTicksAsync(
#    1081                 contract, startDateTime, endDateTime, numberOfTicks,
# -> 1082                 whatToShow, useRth, ignoreSize, miscOptions))
#    1083
#    1084     def reqMarketDataType(self, marketDataType: int):
#
# ~\Anaconda3\lib\site-packages\ib_insync\ib.py in _run(self, *awaitables)
#     290
#     291     def _run(self, *awaitables: Awaitable):
# --> 292         return util.run(*awaitables, timeout=self.RequestTimeout)
#     293
#     294     def waitOnUpdate(self, timeout: float = 0) -> bool:
#
# ~\Anaconda3\lib\site-packages\ib_insync\util.py in run(timeout, *awaitables)
#     309         globalErrorEvent.connect(onError)
#     310         try:
# --> 311             result = loop.run_until_complete(task)
#     312         except asyncio.CancelledError as e:
#     313             raise globalErrorEvent.value() or e
#
# ~\Anaconda3\lib\site-packages\nest_asyncio.py in run_until_complete(self, future)
#      52             f._log_destroy_pending = False
#      53         while not f.done():
# ---> 54             self._run_once()
#      55             if self._stopping:
#      56                 break
#
# ~\Anaconda3\lib\site-packages\nest_asyncio.py in _run_once(self)
#      73             else min(max(0, scheduled[0]._when - now), 10) if scheduled \
#      74             else None
# ---> 75         event_list = self._selector.select(timeout)
#      76         self._process_events(event_list)
#      77
#
# ~\Anaconda3\lib\selectors.py in select(self, timeout)
#     321         ready = []
#     322         try:
# --> 323             r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324         except InterruptedError:
#     325             return ready
#
# ~\Anaconda3\lib\selectors.py in _select(self, r, w, _, timeout)
#     312     if sys.platform == 'win32':
#     313         def _select(self, r, w, _, timeout=None):
# --> 314             r, w, x = select.select(r, w, w, timeout)
#     315             return r, w + x, []
#     316     else:
#
# KeyboardInterrupt:

# %%
df
# Out:
#                                 0      1      2       3      4
# 0       2019-01-07 09:00:00+00:00  400.0  93.00   200.0  94.67
# 1       2019-01-07 09:02:18+00:00  700.0  94.46   700.0  94.66
# 2       2019-01-07 09:02:19+00:00  700.0  94.44   700.0  94.66
# 3       2019-01-07 09:02:19+00:00  700.0  94.44   700.0  94.65
# 4       2019-01-07 09:02:19+00:00  700.0  94.44   700.0  94.64
# ...                           ...    ...    ...     ...    ...
# 270101  2019-01-07 19:53:17+00:00  100.0  95.63  3200.0  95.67
# 270102  2019-01-07 19:53:17+00:00  100.0  95.63  3300.0  95.67
# 270103  2019-01-07 19:53:17+00:00  100.0  95.63  3200.0  95.67
# 270104  2019-01-07 19:53:17+00:00  100.0  95.63  3100.0  95.67
# 270105  2019-01-07 19:53:17+00:00  100.0  95.63  3000.0  95.66
#
# [270106 rows x 5 columns]

# %%
# Append new data collected to the origin dataset
df.columns=['time', 'bidSize', 'bid', 'askSize', 'ask']
df1 = df0.append(df, ignore_index=True)

# %%
df1
# Out:
#                               time  bidSize    bid  askSize    ask
# 0        2019-01-02 09:00:00+00:00    200.0  77.99    700.0  91.11
# 1        2019-01-02 09:00:17+00:00    200.0  77.99    100.0  91.80
# 2        2019-01-02 09:00:25+00:00    200.0  77.99    200.0  93.93
# 3        2019-01-02 09:08:27+00:00    700.0  89.11    700.0  89.34
# 4        2019-01-02 09:08:27+00:00   1400.0  89.11   1400.0  89.34
# ...                            ...      ...    ...      ...    ...
# 1464782  2019-01-07 19:53:17+00:00    100.0  95.63   3200.0  95.67
# 1464783  2019-01-07 19:53:17+00:00    100.0  95.63   3300.0  95.67
# 1464784  2019-01-07 19:53:17+00:00    100.0  95.63   3200.0  95.67
# 1464785  2019-01-07 19:53:17+00:00    100.0  95.63   3100.0  95.67
# 1464786  2019-01-07 19:53:17+00:00    100.0  95.63   3000.0  95.66
#
# [1464787 rows x 5 columns]

# %%
# df.columns=['time', 'bidSize', 'bid', 'askSize', 'ask']
df1.to_csv('SSO_20190101_.csv')
# Out:
# Error 1100, reqId -1: Connectivity between IB and Trader Workstation has been lost.
